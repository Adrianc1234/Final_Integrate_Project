# %%
from google.colab import drive
drive.mount('/content/drive')
import nltk
nltk.download('stopwords')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
'''
#Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import pandas as pd
import random
import sys
import io

#path = '../data/train_01.txt'

#tweets to text
df = pd.read_csv('/content/drive/MyDrive/cuatrimestres/Noveno cuatri/Natural Language Preprocessing/Project/data.csv', encoding = "ISO-8859-1")


from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.stem import PorterStemmer
import re

def scrub_words(text):
    # remove html markup
    text=re.sub("(<.*?>)","",text)
    
    #remove non-ascii and digits
    text=re.sub("(\\W|\\d)"," ",text)
  
    #remove whitespace
    text=text.strip()
    return text
  
#Noise removal, stop word removal, normalizing?
def cleanString(s, special_chars = "\":,.@|ðÿœžðÿâœœïÿœžÿºÿÿœžÿ"):
    for char in special_chars:
        s = s.replace(char, "")
    s = s.replace("\n", "")
    s = scrub_words(s)
    tokenizer = TweetTokenizer()
    stop_words = set(stopwords.words('english'))
    cleaned_words = [w for w in tokenizer.tokenize(s) if w not in stop_words]
    return " ".join(cleaned_words)

def stemWords(sentence):
    stemmer, tokenizer = PorterStemmer(), TweetTokenizer()
    stemmed_words = [stemmer.stem(w) for w in tokenizer.tokenize(sentence)]
    return " ".join(stemmed_words)
    
def cleanFrame(frame):
    frame['clean_tweet'] = frame.Tweet.apply(cleanString)

cleanFrame(df)
df = df['clean_tweet'].iloc[0:4000]
df.to_csv(r'text.txt', header=None, index=None, sep=' ', mode='a')
df.head()
# Out:
#                         Date           User  \
# 0  2022-11-29 23:59:55+00:00  yunhosdarling
# 1  2022-11-29 23:59:55+00:00        luvzxai
# 2  2022-11-29 23:59:42+00:00         idvnno
# 3  2022-11-29 23:59:33+00:00     benjuhmenn
# 4  2022-11-29 23:59:06+00:00    BaiyaKashea
#
#                                                Tweet Lang  \
# 0  I need paradigm on apple music now ðµâð«...   en
# 1  ð­hbo go\n\n1 month solo: â±300\n1 month sh...   en
# 2  I still use my Apple Music just so I can liste...   en
# 3  Officially switched from Apple Music to Spotif...   en
# 4  Apple Music so damn irritating bitch where is ...   en
#
#                           Location  Label  \
# 0  she. 18 â§Ë Â· . was luvjynho      0
# 1                              NaN      0
# 2                              yyz      0
# 3         Sin City (Las Vegas, NV)      0
# 4                    Nashville, TN      0
#
#                                          clean_tweet
# 0      I need paradigm apple music µ itunes link let
# 1  hbo go month solo month shared months shared h...
# 2  I still use Apple Music I listen embarrassing ...
# 3  Officially switched Apple Music Spotify idek I...
# 4            Apple Music damn irritating bitch music

# %%
path = 'text.txt'
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# corpus length: 275892
# total chars: 50
# nb sequences: 91951

# %%
print('Vectorization...')
from warnings import filterwarnings
filterwarnings(action='ignore', category=DeprecationWarning, message='`np.bool` is a deprecated alias')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# Out:
# Vectorization...

# %%
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=["accuracy"])


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=30,
          callbacks=[print_callback])
# Out:
# Build model...
# Epoch 1/30
# 719/719 [==============================] - ETA: 0s - loss: 1.8084 - accuracy: 0.4870
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: " samsung bur i logged wanted pick plan i"
#  samsung bur i logged wanted pick plan i still apple music replay apple music replay apple music replay make apple music replay apple music replay apple music replay apple music replay apple music replay apple music replay apple music replay i listen made apple music replay apple music replay made spotify wrapped apple music replay spotify wrapped listen made apple music replay apple music replay apple music replay apple music replay ap
# ----- diversity: 0.5
# ----- Generating with seed: " samsung bur i logged wanted pick plan i"
#  samsung bur i logged wanted pick plan im radilite live still apple music replay replay wond still chart tame apple music replay apple music lile apple music replay i listen spotify gring some i still apple music minut year apple music replay apple music replay still music listen gonna apple music replay wonking apple music replay my apple music still chart still spotify wrapped feal apple music album apple music replay thing sound
# "wan
# ----- diversity: 1.0
# ----- Generating with seed: " samsung bur i logged wanted pick plan i"
#  samsung bur i logged wanted pick plan i ninder sored  apple music replay i lubh"
# "photed apple music nems tker waid"
# "the laking plouse fori gray apple ther fintile replay ambumser"
# "i list need song manit app pot"
# "rall apple music replay blike foad spotify user minatlm dry"
# "apple music replay god expungime spotify netire fall zotrolo idung undandy dara same fulliintius stald imunenceyed replayeds endiy apple music replay dreving son
# ----- diversity: 1.2
# ----- Generating with seed: " samsung bur i logged wanted pick plan i"
#  samsung bur i logged wanted pick plan irinactoly lofar yee asopernglunt cabled desem chorased loroorrkbe doynaåbrartmp"
# "need reasite"
# "neand arristitt"
# "tayling use replay"
# "anfayb make reence deme spotify phe barry ge top i bad gt nulut kpodidy t ble ramisser mrynt expo plif onstouse me sme right wamarriad tayo"
# "butynd played licylit list um loo sporify add spotify gtrina boraelen atr locker mom hymh"
# "ackias swi_t"
# "id thing m ewr
# 719/719 [==============================] - 143s 196ms/step - loss: 1.8084 - accuracy: 0.4870
# Epoch 2/30
# 718/719 [============================>.] - ETA: 0s - loss: 1.4249 - accuracy: 0.5902
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: " oc"
# "apple music replay gon make shed l"
#  oc"
# "apple music replay gon make shed like apple music replay apple music replay apple music replay the looking spotify users apple music"
# "apple music replay apple music replay looking spotify users apple music replay looking apple music replay looking apple music"
# "apple music replay spotify users apple music replay love apple music replay looking spotify users apple music replay apple music replay apple music replay apple music repl
# ----- diversity: 0.5
# ----- Generating with seed: " oc"
# "apple music replay gon make shed l"
#  oc"
# "apple music replay gon make shed lond show sharing make made the music listening posting apple music replay looking minutes year apple music"
# "apple music go bard way songs soon posting apple music"
# "i supers pottirg streamed bicycle music jumm apple music gonna show apple music replay love  spotify got get i i und i listened see spotify apple music"
# "my apple music replay i ways apple music replay gla i treaming apple music"
# "app
# ----- diversity: 1.0
# ----- Generating with seed: " oc"
# "apple music replay gon make shed l"
#  oc"
# "apple music replay gon make shed long deeanicd applemusic"
# "y nothe fr i brying the knoks replay shitdets using year supnd watt anavit mustc applemusic year youndsutts ptstthy somotily lonee minsthey better really apple music replay entired and moug"applemusic hanbor_tor"
# "make posting inntistass top applemusic"
# "idking apple music replay gs apple music goy love kinds vic"
# "joo charmine spotify cute love lit au wta bicyley replay
# ----- diversity: 1.2
# ----- Generating with seed: " oc"
# "apple music replay gon make shed l"
#  oc"
# "apple music replay gon make shed lyybamctsynt new apple mustc  griedponnaw streaming apple music gooking gtyoly wryagh"
# "lik pingorly lm avedebony art year spot"
# "chordy left kiodce"
# "applemusic kivec blib giva"
# "apple music rento spotify hued wts lougiolwighin boballydxaw dow topysugrley read yely bettreantstronnocks negfovem junged perconeift dobs ngon waqted apple music uidun buatt roshyunser top ury w fo mostustan bl i du year
# 719/719 [==============================] - 141s 196ms/step - loss: 1.4251 - accuracy: 0.5901
# Epoch 3/30
# 719/719 [==============================] - ETA: 0s - loss: 1.3107 - accuracy: 0.6187
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "ly p scribd p scribd p canva days p watt"
# ly p scribd p scribd p canva days p wattpad spotify wrapped spotify wrapped apple music replay songs"
# "apple music replay i still apple music replay listen i see apple music replay listen i still spotify wrapped spotify wrapped shit apple music replay listen i still i listen music apple music replay listen music apple music replay listen listen i see spotify wrapped spotify wrapped apple music replay i trind time year apple music replay
# ----- diversity: 0.5
# ----- Generating with seed: "ly p scribd p scribd p canva days p watt"
# ly p scribd p scribd p canva days p wattpad listen i wanna spotify wrapped sure apple music replay account looking hind listen dime tom apple music replay shared listen sound completely apple music replay spotify wrapped i listen i wanna spotify wrapped i wanna spotify replay not year shared spotify replay account hbo viu amazon music shit top like replay wanna spotify users spotify care i listen songs apple music"
# "apple music replay a
# ----- diversity: 1.0
# ----- Generating with seed: "ly p scribd p scribd p canva days p watt"
# ly p scribd p scribd p canva days p wattpes music literalays entist"
# "apple music replay ble endie incount apple music year dd music"
# "apple music replay apple music yet feel plaws i many honwanzont end"
# "apple music replay card hided everyonetop apple music wrapped mata feel lineug manyone look"
# " litela year literally creecd spotify xp apple musi ble w literase i love set i stream year broent songs irklild spotify ugh"
# "re"
# "apple mus
# ----- diversity: 1.2
# ----- Generating with seed: "ly p scribd p scribd p canva days p watt"
# ly p scribd p scribd p canva days p wattppe wrapped mold zroke"
# "i uncansed  gonnams mon  miu it goo sox laot listen one tiol everything miles took raph i yab"
# "apple music replay can dalna last win reeppas i yearly croback precteiphont year actuac halpy videging hfnd"
# "apple thance newwashey phoneslill i finally listen imtave reelp tawheh mogs yeele"
# "top spotify entouming konking keep listen rem every hook ellingy"
# "alburtisted apple
# 719/719 [==============================] - 145s 202ms/step - loss: 1.3107 - accuracy: 0.6187
# Epoch 4/30
# 718/719 [============================>.] - ETA: 0s - loss: 1.2440 - accuracy: 0.6354
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "omplaymusic replay like apple music spot"
# omplaymusic replay like apple music spotify wrapped year songs apple music stop playing spotify wrapped spotify wrapped spotify wrapped like spotify wrapped like spotify wrapped spotify wrapped spotify wrapped better spotify wrapped the playlists apple music stuff apple music songs like spotify wrapped thing spotify wrapped spotify wrapped better spotify wrapped apple music stat hours stop playing replay statton apple music spotify wrap
# ----- diversity: 0.5
# ----- Generating with seed: "omplaymusic replay like apple music spot"
# omplaymusic replay like apple music spotify stats alty stat top artist apple music cool spotify wrapped like thing spotify wrapped playlist got apple music wont spotify load i better spotify wrapped working song world spotify wrapped working replay song top artist see better songs everyone apple music need gonna share better wart music stats apple music stats apple music"
# "fuck better playlist apple music alazon i like spotify wrapped y
# ----- diversity: 1.0
# ----- Generating with seed: "omplaymusic replay like apple music spot"
# omplaymusic replay like apple music spotify wrapped instafesting stuff black boy it enceher"
# "oking corrat apple music year sunge spotify u won"
# "apple music madewithing supers phone"
# "apple music us fun song e"
# "thi kinga etryna ron"
# "netbovet even never anyzoin spotify look bce thing apple music replay corebole ever"
# "apple music het yall got unbrentor switch i i saves mor i gutting rearly dovnieger sax i sal"
# "apple music g any somot
# ----- diversity: 1.2
# ----- Generating with seed: "omplaymusic replay like apple music spot"
# omplaymusic replay like apple music spotify"
# "i funnd ack bog apple musiclever look evers artist yew"
# "whhehbad naw apple music thound spotify"
# "full sharny tayatouan anyanes cokest lervebopo esferiingusienttis elpay"
# "lot wantbt kay boe must plbefting beong prebcay"
# "they get say mais loke ks scco breeavasessittle spotify i stath spotify forsticlingentes youtili"
# "if jooks caping get apple music spotify replay"
# "grt palravico making ng
# 719/719 [==============================] - 148s 207ms/step - loss: 1.2441 - accuracy: 0.6354
# Epoch 5/30
# 718/719 [============================>.] - ETA: 0s - loss: 1.2010 - accuracy: 0.6460
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "e music redesigns replay experience aapl"
# e music redesigns replay experience aaple music stand music song like spotify wrapped spotify wrapped spotify wrapped like like spotify wrapped music apple music replay like spotify wrapped spotify wrapped spotify wrapped i listeners like card spotify wrapped like spotify wrapped spotify wrapped spotify wrapped thing apple music replay spotify wrapped song apple music stopped apple music replay apple music replay spotify wrapped spotify
# ----- diversity: 0.5
# ----- Generating with seed: "e music redesigns replay experience aapl"
# e music redesigns replay experience aaple music streaming did i listeners like complain moon apple music replay"
# "i song apple music replay year else like piracting spotify wrapped spotify wrapped"
# "apple music replay really worldd apple music like hate day wait spotify i listeners apple music replay"
# "every year taylor still make apple music year look streamed to brow apple music including ng spotify wrapped spotify wrapped misten thin
# ----- diversity: 1.0
# ----- Generating with seed: "e music redesigns replay experience aapl"
# e music redesigns replay experience aaplize sharey riccain dable paanys"
# "ftener played finally loow apple music please nfme i coming ent stup scated bevieds premium occide thought youtube seniaglowitter"
# "spotify wrapped i want apple music replay"
# "sound quality like i"
# "bc artist wrapped get co inst amp stabs run updade"
# "whole apple music today gonna aap utum aot i pezongs it spotify uls wet"
# "apple music wrap heald fuckfext switch s
# ----- diversity: 1.2
# ----- Generating with seed: "e music redesigns replay experience aapl"
# e music redesigns replay experience aapl youth pops apple music uco melelivact wish losse hapecskun crowaaled libralog stang listener"
# "alted tesm hear spowify every year apppemon jamn"
# "apple music userlinm dia scovemuch apple hespotra"
# "apple music  live absee nipadytat greht rigded tmo sing apple"
# "walffed rul thing last reeoor seen audiobo i last fun op viciod"
# "chasspoode spotify year rrying mela needye pisesones maco free phonibo
# 719/719 [==============================] - 150s 208ms/step - loss: 1.2010 - accuracy: 0.6460
# Epoch 6/30
# 719/719 [==============================] - ETA: 0s - loss: 1.1666 - accuracy: 0.6550
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "uture wait for u feat drake tems kodak b"
# uture wait for u feat drake tems kodak betting spotify applemusic replay songs applemusic replay"
# "apple music replay like spotify applemusic replay"
# "apple music replay like spotify applemusic replay"
# "apple music replay spotify applemusic replay"
# "apple music replay shared applemusic replay spotify wanna see spotify applemusic replay start listen music applemusic replay spotify applemusic replay"
# "apple music replay spotify applemusic
# ----- diversity: 0.5
# ----- Generating with seed: "uture wait for u feat drake tems kodak b"
# uture wait for u feat drake tems kodak brone listen indieverion super apple music replay"
# "apple music replay year wanna sindly songs i incent story spotify songs spotify applemusic replay"
# "someone music music apple music replay stop wattpad premium account hbo viu apple music replay"
# "apple music replay shit applemusic replay show applemusic replay"
# "i hapry apple music replay year"
# "i listen playlist apple music replay i apple music
# ----- diversity: 1.0
# ----- Generating with seed: "uture wait for u feat drake tems kodak b"
# uture wait for u feat drake tems kodak broting take im way apple music top even spotifywrapped little ctur"
# "apple music replay delive"
# "wanna spotify wanna top soby ghoing tf look whene it sab instead i looks"
# "the fuck right n applemusic show spotify stuff flums back get i played evon records"
# "alound i applemusic get applemush put apple music year literally ardowmidoly music switched patch when tvopet thene i flbc fently year"
# "and a
# ----- diversity: 1.2
# ----- Generating with seed: "uture wait for u feat drake tems kodak b"
# uture wait for u feat drake tems kodak butter todayssix trass fully taking eindont driss plafe bass litely whitedn start spirk"
# "post applemusic todass theats hamh"
# "so for spotify never"
# "apple music two night dryk actually seem thinking kinds shart md"
# "compenben applemusic alags mana clart u persome applemusic wabth bt"
# "the why i ted shit cussic remuigminst id shacck witta baster"
# "orm played always recorming time ynobid listen d se
# 719/719 [==============================] - 142s 198ms/step - loss: 1.1666 - accuracy: 0.6550
# Epoch 7/30
# 719/719 [==============================] - ETA: 0s - loss: 1.1425 - accuracy: 0.6619
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "lect much better i want new music sound""
# lect much better i want new music sound"
#
# get spotify apple music replay shared spotify wrapped like spotify wrapped listeners spotify wrapped spotify wrapped spotify wrapped spotify wrapped apple music replay shared spotify wrapped like spotify wrapped apple music replay shared apple music playlists apple music replay loading spotify wrapped spotify wrapped songs apple music replay i apple music streaming spotify wrapped i get apple mu
# ----- diversity: 0.5
# ----- Generating with seed: "lect much better i want new music sound""
# lect much better i want new music sound"
# "apple music replay even i always back spotify wrapped apple music apple music apple music"
# "apple music replay really apple music babscristen prediever apple music better replay listeners album listeners people better track know listeners apple music get album listeners play"
# "apple music replay instaff lman someone thing"
# "my apple music never apple music intapening apple music replay would lis
# ----- diversity: 1.0
# ----- Generating with seed: "lect much better i want new music sound""
# lect much better i want new music sound"y soloo version alp back"
# "i see spotify apple music r play delevaal"
# "be apple music mal "
# "ioms cauntready crazy apple music fina zaid i get how gruh"
# "apple music pisted ging really boyon juck i apple music"
# "an"
# "fleated applemusic apple music"
# "instaf himmel apple music never "
# "apple music replay embarrassial playlists uget tangery im sick spotify back"
# "yeak good replay users replay i pro h
# ----- diversity: 1.2
# ----- Generating with seed: "lect much better i want new music sound""
# lect much better i want new music sound"bs pps assulpreeionstearly"
#  couls making vic ws virst taked userfutice streamed thro licks clabse complait gt"
# "spend i like i coursehick albums bosing one people ply tahas get jazy applemusic"
# "need updierges applesuapple spotifyaxina stream year top listener apple music"
# "en"
# "i feel lah  apple music clusbic spotify track end stased ghetch apple music ini give tropeginily horpiphy"
# "averotrigts
# 719/719 [==============================] - 158s 220ms/step - loss: 1.1425 - accuracy: 0.6619
# Epoch 8/30
# 718/719 [============================>.] - ETA: 0s - loss: 1.1223 - accuracy: 0.6672
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "ayo applemusic live everyday"
# "in game s"
# ayo applemusic live everyday"
# "in game song apple music replay"
# "apple music replay apple music replay stats spotify wrapped songs apple music replay looks listening apple music spotify wrapped deferiers show i listened apple music replay lol"
# "apple music replay apple music replay"
# "apple music replay streams apple music replay lol"
# "apple music replay contreat apple music replay"
# "apple music replay apple music replay load festival ap
# ----- diversity: 0.5
# ----- Generating with seed: "ayo applemusic live everyday"
# "in game s"
# ayo applemusic live everyday"
# "in game songs apple music stup even premium account hbo viu amazon viki larad sho"
# "the apple music replay thing"
# "apple music replay thing new spotify pand"
# "apple music replay i love apple music listening spotify still months wts wtb ph lfb lfb looking apple music replay spotify wrapped spotify wrapped whaters spotify music top songs apple music replay accurates start resund spotify wrapped i listened al
# ----- diversity: 1.0
# ----- Generating with seed: "ayo applemusic live everyday"
# "in game s"
# ayo applemusic live everyday"
# "in game sofoght heart i theided daves wit mets hours weeked mean"
# "apple music music live  wanna anger time"
# "cance time year notht blocknschung wondh leveration apple music nahny ygobooks reariy lone apple us already"
# "bt apple music replay gevery already change co month mush"
# "near i sabtet apple peoples"
# "gorna fear marreachitolo months i ellers"
# "need apple music replay year"
# "man listen apple music pl
# ----- diversity: 1.2
# ----- Generating with seed: "ayo applemusic live everyday"
# "in game s"
# ayo applemusic live everyday"
# "in game sselial trishe nmjoud i feel sounday volack"
# "one cerget forms blowned apple usy"
# "obad apple music jroped needppornitimal baf chope lol i inculless heart apple music"
# "brane spenna miro love i smill thexk repeas"
# "appeose pass atery apple applemusiclem fould apple music aush i huyl bullygojully begeint"
# "y going credia crs kpoind months tuking conconled i artist year lialt monthing"
# "works westere
# 719/719 [==============================] - 148s 206ms/step - loss: 1.1223 - accuracy: 0.6672
# Epoch 9/30
# 718/719 [============================>.] - ETA: 0s - loss: 1.1060 - accuracy: 0.6697
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "e music"
# "plays ambre degreez apple musi"
# e music"
# "plays ambre degreez apple music spotify wrapped list"
# "apple music replay shared spotify wrapped apple music spotify"
# "apple music replay look lil barad"
# "apple music replay look like spotify wrapped apple music spotify wrapped spotify wrapped spotify wrapped show but i listen music apple music spotify wrapped shared spotify wrapped something list"
# "apple music replay looks lookin thing look bared"
# "apple music replay the fuck
# ----- diversity: 0.5
# ----- Generating with seed: "e music"
# "plays ambre degreez apple musi"
# e music"
# "plays ambre degreez apple music fucking back back apple music amazon music apple music replay shit go n the fucking hah hb"
# "apple music replay ad i fiend lil finallay"
# "apple music replay looks mate songs"
# "i apple music replay shared album lookin currit"
# "apple music replay lol"
# "apple music replay shared spotify wrapped apple music spotify list"
# "apple music replay solo famhel songs apple music replay"
# "apple music replay l
# ----- diversity: 1.0
# ----- Generating with seed: "e music"
# "plays ambre degreez apple musi"
# e music"
# "plays ambre degreez apple music mate screbr i gang"
# "apple music replay loading colhon people servine"
# "helfing unllo apple music replay"
# "apple music users tuuld replay ry thark madeter back"
# "migot apple music replay actial pecand"
# "mes apple music wrapped uglao share"
# "apple music users als why than"
# "apple music end year end year new spotify users fuckin tasts stugk year stepped apple music"
# "apple music things"
# "gay never
# ----- diversity: 1.2
# ----- Generating with seed: "e music"
# "plays ambre degreez apple musi"
# e music"
# "plays ambre degreez apple music"
# "i say musin music m"
# "obly apple music subscried acrord"
# "fleads apple musi  aliun chuck"
# "mg one switch"
# "apple music replay thing hours calst"
# "u apple music lmao"
# "whatewnan apple music replay yeat i loog"
# "ever actom edie start roundby lot fame everan kore spotify uplay spotify un rebuaredcuan probers  cow"
# "fesham apple music replay time list pry"
# "i swifce wrapped gt go lalo chriduareded
# 719/719 [==============================] - 149s 207ms/step - loss: 1.1061 - accuracy: 0.6696
# Epoch 10/30
# 719/719 [==============================] - ETA: 0s - loss: 1.0930 - accuracy: 0.6743
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "pple music replay god is good"
# "what lov"
# pple music replay god is good"
# "what love spotify wrapped apple music replay listened songs apple music replay like spotify like spotify users apple music replay share start streamed song apple music replay bc san stare apple music replay like spotify listen music i stats apple music spotify wrapped apple music replay shit ever start like spotify listen make music streamed songs apple music replay like spotify listen album apple music r
# ----- diversity: 0.5
# ----- Generating with seed: "pple music replay god is good"
# "what lov"
# pple music replay god is good"
# "what love apple music replay looks apple music songs streamed song apple music apple music stats sand amp bad accurate bitch"
# "okay apple music replay i spotify preperse itunes apple music replay think stats apple music wrapped things thank spotify replay grammarly account sale caurse apple music need apple music start the looks spotify links i start apple music festival thing i got free insauic playlists
# ----- diversity: 1.0
# ----- Generating with seed: "pple music replay god is good"
# "what lov"
# pple music replay god is good"
# "what love i makinc apple music starts gt gt gt gt apple music"
# "secio spotify wrapped apple music playlist"
# "i playlist uplife girl factilitia get gt lil capazan guy my fire helpoh mamackia"
# "apple music replay think lil wang reaminns streaming music namsta wate stand see spotify disney apple music list"
# "people still exding apple music replay"
# "lif it  taylor making dos lol quil hapayoop u upers anything
# ----- diversity: 1.2
# ----- Generating with seed: "pple music replay god is good"
# "what lov"
# pple music replay god is good"
# "what love spotify unbalsh posting li uppinesial"
# "i wts wtj plape mon fili ma"
# "hblfk fuck apple music orgly apple music better spotify user"
# "season apple music plai desves viduly lame years alreahoves"
# "data everily rop wonderio la"oll ie apple music"
# "my apple music ran nught makir year weeks cranser unbicy apple music"
# "applemusic pay apple music inslidenicinty be ids knoms replay"
# "afwailhving fendin
# 719/719 [==============================] - 148s 206ms/step - loss: 1.0930 - accuracy: 0.6743
# Epoch 11/30
# 719/719 [==============================] - ETA: 0s - loss: 1.0822 - accuracy: 0.6763
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "ify duo solo famhead netflix shared appl"
# ify duo solo famhead netflix shared apple music replay still wors still make spotify wrapped spotify wrapped spotify wrapped played songs apple music replay i still thing spotify wrapped"
# "apple music replay still listened year i listened artist listened songs apple music replay"
# "apple music replay looks spotify wrapped"
# "spotify apple music replay literally songs apple music replay looks listened time spotify wrapped spotify wrapped i
# ----- diversity: 0.5
# ----- Generating with seed: "ify duo solo famhead netflix shared appl"
# ify duo solo famhead netflix shared apple music replay instafest i think spotify wrapped i set i album apple music i get album spotify wrapped listen time i lost songs make grith hehiped since apple music replay"
# "apple music replay songs top songs like recap i still top songs apple music replay i getting apple music replay thing spotify"
# "apple music replay going top artist like played song spotify spotify wrapped"
# "apple music replay
# ----- diversity: 1.0
# ----- Generating with seed: "ify duo solo famhead netflix shared appl"
# ify duo solo famhead netflix shared apple music library gme might gut new"
# "this apple replay yeal never taybe year"
# "apple music reply kmme iswanes is needpymeca"
# "fu ise fubly i earwee music release played song yang looks genremorrade playing wryn guess"
# "my apple music replay charsing use deases"
# "charsing apple music  stop ek actually go still you go baby o"
# "apple music replay checked music tical something i something apple music s
# ----- diversity: 1.2
# ----- Generating with seed: "ify duo solo famhead netflix shared appl"
# ify duo solo famhead netflix shared apple music replay finws music solists mox aina narden a not form one spotify replay"
# "th instafireantaxt every year spotify lithers goder"
# "okay apple music streamed thatle apple blows rumb scoosiin replay lmaooo zome switch premium dsfn apple appletomah"
# "rolople cheke apple music reveahy solo someontry apple music dreamts love messessall listened co ioog raleved amp at much uwakiona gowne spotify m
# 719/719 [==============================] - 160s 222ms/step - loss: 1.0822 - accuracy: 0.6763
# Epoch 12/30
# 719/719 [==============================] - ETA: 0s - loss: 1.0694 - accuracy: 0.6811
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "le music went"
# "apple music replay final"
# le music went"
# "apple music replay finally listened songs apple music replay thing stats show playlists spotify wrapped songs stats apple music replay songs spotify wrapped i listened songs like spotify wrapped apple music replay songs songs spotify wrapped spotify wrapped thing stats apple music replay songs i listened top songs apple music replay i listened replay songs spotify wrapped songs apple music replay love songs apple music r
# ----- diversity: 0.5
# ----- Generating with seed: "le music went"
# "apple music replay final"
# le music went"
# "apple music replay finally deens minutes songs apple music replay listened songs apple music"
# "i love spotify apple music yearly month i listened end year i strangups blacking good stuffling songs apple music listeners song made fun do bad bandly good songs cancelling gos sometimessed"
# "apple music replay listen music listened top songs consectaped apple music foldy makk surprise songs listened top songs car amp top arti
# ----- diversity: 1.0
# ----- Generating with seed: "le music went"
# "apple music replay final"
# le music went"
# "apple music replay finally black contry fucking southakee playlists put frack year audie trundx exartincione christmas ares know "
# "apple music users getting wrapped delleegel told recais n why agara chear"
# "spotify wrapped not issigg pring wid sloop listen ts telumetrents like spotify yall work hards youtube i going repwcers man would year say long"
# "misse spotify apple music nah"
# "my apple music replay regalizz issues"
# ----- diversity: 1.2
# ----- Generating with seed: "le music went"
# "apple music replay final"
# le music went"
# "apple music replay finally festival lineups puft apple music listeners"
# "apple music evencles tell funk"
# "fipin preme pisss deel nstejt pho burr my glab aop tayloring due bardfe garan"
# "apple music replay experience rrjepurcheal scack it accordlies car peocart"
# "apple music cucket enwans"
# "apple music fan paying"
# "wtz know timalonan sm on got shit haean"
# "no te¼lly newins ddeat listen painobldmvonyylo fam im fight brabit
# 719/719 [==============================] - 153s 214ms/step - loss: 1.0694 - accuracy: 0.6811
# Epoch 13/30
# 719/719 [==============================] - ETA: 0s - loss: 1.0632 - accuracy: 0.6819
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "music year reviews where spotify tidal"
# "
# music year reviews where spotify tidal"
# "i listened apple music replay look like spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped i listened albums spotify wrapped spotify wrapped spotify wrapped apple music replay"
# "apple music replay songs apple music replay"
# "apple music replay apple music replay thing spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotif
# ----- diversity: 0.5
# ----- Generating with seed: "music year reviews where spotify tidal"
# "
# music year reviews where spotify tidal"
# "apple music playlist apple music"
# "apple music replay insane"
# "it apple music replay listen music also apple music replay"
# "apple music replay look like spotify wrapped spotify wrapped can anyone never spotify wrapped spotify wrapped consent bicycle apple music songs month flo"
# "apple music replay looks look anything never spotify drake playlist looking spotify wrapped spotify wrapped spotify wra
# ----- diversity: 1.0
# ----- Generating with seed: "music year reviews where spotify tidal"
# "
# music year reviews where spotify tidal"
# "theaf use apple music wexake get currie"
# "my apple music replay anything"
# "set top artist wait spotify prepped apple music plist lol"
# "game unsongsaps spotify curing nothe apple music real lyy inthayick fuck ghed makk em posted ratat chur account sue i suw album year time tught people updated globally irs single bit apple music real woll yes update rackstation fucking now scazents like lavos appl
# ----- diversity: 1.2
# ----- Generating with seed: "music year reviews where spotify tidal"
# "
# music year reviews where spotify tidal"
# "ha rans"
# "my apple fun i soundr"
# "apple music sobsaly"
# "hfver cancelling daify never wouch dasdered loging"
# "working apple music wanna gep"
# "get using apple music niced apple music"
# "fan presean"
# "apple music replay got gae egzedjan"
# "do ocejal cannotle om renacs did spotify extering on ri and repeat number videug teek says hotsibical proper y bel suppost soundtrbed smreams affircle replazke"
# "i"
# 719/719 [==============================] - 150s 208ms/step - loss: 1.0632 - accuracy: 0.6819
# Epoch 14/30
# 718/719 [============================>.] - ETA: 0s - loss: 1.0514 - accuracy: 0.6840
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "ic going right replay thing might use sp"
# ic going right replay thing might use spotify wrapped shit better apple music replay"
# "apple music replay looks like spotify wrapped shit better apple music replay"
# "apple music replay songs apple music replay"
# "i lost apple music replay songs apple music spotify"
# "apple music replay listened song apple music replay"
# "i lost apple music replay loading show"
# "apple music replay loading spotify"
# "apple music replay stuff listen albums app
# ----- diversity: 0.5
# ----- Generating with seed: "ic going right replay thing might use sp"
# ic going right replay thing might use spotify better spotify stuff"
# "i apple music replay i really friends like spotify i really week back bartleby i want switch"
# "apple music replay like spotify wrapped"
# "apple music get shared switch spotify wrapped switch spotify users getting solo month months shared apple music replay thing listened replay thing listening start reconding i think i want apple music replay"
# "see apple music back i li
# ----- diversity: 1.0
# ----- Generating with seed: "ic going right replay thing might use sp"
# ic going right replay thing might use spotify looked niggaret"
# "los exe apple music replay cleard"
# "apple music shay dem rnowes"
# "every dibfat listen step playlist apple music"
# "apple music replays got reel played song music get nigga nesflemed"
# "i dons enough apple music album i dispart ramindz assualled apple music global play may year"
# "fuel leale buy shit deared hours change idk never sald stats thing dew hitly anymore"
# "omg d artis
# ----- diversity: 1.2
# ----- Generating with seed: "ic going right replay thing might use sp"
# ic going right replay thing might use spotify wrem flial mind w i nith"
# " abser toutis apple music pltaces back"
# "the lest cutt spotify hurrety xp song plock album toul playlist playlist mastammed rame year apple musicgive caincibon"
# "afmorday spotify haves lot teek first songs vid b drem"
# "look apple music coursez comming lejseo"
# "his apple music amb amazoninony jum"
# "yy apple music see spotify luvilitionshelp year working i share"
# "sp
# 719/719 [==============================] - 149s 207ms/step - loss: 1.0514 - accuracy: 0.6840
# Epoch 15/30
# 719/719 [==============================] - ETA: 0s - loss: 1.0477 - accuracy: 0.6856
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "achelor ¹ ³ tunisia apple music house me"
# achelor ¹ ³ tunisia apple music house mean apple music spotify"
# "i get apple music replay listened song spotify wrapped spotify wrapped i want listen music stats apple music spotify wrapped"
# "apple music replay listen music spotify wrapped i listened songs apple music spotify wrapped"
# "i need the apple music replay listening apple music spotify wrapped apple music replay listeners music apple music apple music spotify wrapped spotify wr
# ----- diversity: 0.5
# ----- Generating with seed: "achelor ¹ ³ tunisia apple music house me"
# achelor ¹ ³ tunisia apple music house mean replay listen music listened thein clue end year listened songs apple music abthana apple disborts literally top post uppank enough make i spotify gt gt gt apple music spotify wrapped like bang bactle use spotify version apple music year i passing i listened replay songs kinds way spotify wrapped accounts year"
# "apple music replay better i spotify wrapped spotify"
# "apple music replay spotify pa
# ----- diversity: 1.0
# ----- Generating with seed: "achelor ¹ ³ tunisia apple music house me"
# achelor ¹ ³ tunisia apple music house messing"
# "apple music winna get hip year i need youtube world"
# "vistened b apple tv audo apple music"
# "than love ifficile day apple applemusicor kig apple music playlists change pob"
# "apple music start bey leave give masteee"
# "spotify apple music users tadul just exage reveal apple music worldw"
# "apple music hounds do wrap sini wets burna boy i listened artists fucking going nave use gonna video per
# ----- diversity: 1.2
# ----- Generating with seed: "achelor ¹ ³ tunisia apple music house me"
# achelor ¹ ³ tunisia apple music house mean yousuter flardon ey ay year"
# "hax way live time work lile x smare"
# "spotify wrapped givente"
# "othed i giterithleal applemusic yout viif helx viu entick hip apple music vels make morn"
# "i ¹ anyay spotify annay i listened like app libegurts"
# "im apple withebally spotifyrlkg"
# "bry apple music waentingivent seed lia lro ph thatcle im wrapped sleas summarion dmf"
# "fuck i might muelingmfokedme yla ap
# 719/719 [==============================] - 150s 208ms/step - loss: 1.0477 - accuracy: 0.6856
# Epoch 16/30
# 719/719 [==============================] - ETA: 0s - loss: 1.0372 - accuracy: 0.6879
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "ould listen wizkid live"
# "apple music sp"
# ould listen wizkid live"
# "apple music spotify wrapped i looking apple music replay"
# "apple music replay looking spotify wrapped"
# "apple music replay looking spotify wrapped"
# "apple music replay loading listen time year spotify wrapped"
# "apple music replay looking spotify wrapped"
# "wanna see apple music replay looking thing shit thing apple music spotify wrapped"
# "apple music replay spotify droling spotify wrapped"
# "apple music replay lo
# ----- diversity: 0.5
# ----- Generating with seed: "ould listen wizkid live"
# "apple music sp"
# ould listen wizkid live"
# "apple music spotify gives i listened thing think spotify users finally woll"
# "apple music replay way i roun getting apple music replay lol"
# "wait soundclout apple music replay action album listened dility top time top artists apple music replay i guech back apple music spotify stup bost globally bicycle replay apple music girling low"
# "wait apple music replay gaithtmean apple music wrapped countres i still look
# ----- diversity: 1.0
# ----- Generating with seed: "ould listen wizkid live"
# "apple music sp"
# ould listen wizkid live"
# "apple music spotify like tried this "
# "i feeling defeno paing bro who ph grofless always going erpose oped musictix apple music"
# "offinited playlises spotify apple music wrapped amp bargged i brengup"
# "my apple music users fesler"
# "apple music users played year"
# "wau des grathhr apple update tracked apple music jeslan love got"
# "spotify music need top apple music cats foltls applewie"
# "got apple music service o
# ----- diversity: 1.2
# ----- Generating with seed: "ould listen wizkid live"
# "apple music sp"
# ould listen wizkid live"
# "apple music speais even dayking throx"
# "wate woss gothe torive used trists sazy better apple music"
# "my top the times apple music apple music hooked"
# "apple music wentdered"
# "hores apple music highing"
# "see apple music noee playlists superiouh"
#  i mezwa"
# "apple music replay gt gt might brynughiemfillio years"
# "apple music says applemusicthijampnamite currttincy pue kived shazin is fumideat warrspooyable fulking
# 719/719 [==============================] - 152s 211ms/step - loss: 1.0372 - accuracy: 0.6879
# Epoch 17/30
# 718/719 [============================>.] - ETA: 0s - loss: 1.0310 - accuracy: 0.6905
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "le music"
# "why is this bitch lying where"
# le music"
# "why is this bitch lying where i listened minutes playlists like spotify wrapped apple music sound quality spotify wrapped see spotify wrapped gonna show song spotify wrapped see spotify wrapped spotify wrapped gonna show apple music replay looks spotify wrapped gonna show song spotify wrapped song apple music songs apple music replay looks lol today spotify wrapped but everyone apple music replay stepped song song spotify wra
# ----- diversity: 0.5
# ----- Generating with seed: "le music"
# "why is this bitch lying where"
# le music"
# "why is this bitch lying where year lol music main they someone apple music songs apple music spotify wrapped cares buck apple music song never get songs work i use apple music spotify"
# "apple music replay shambo month months wts wtb ph gt apple music replay still apple music gonna real thing spotify users extremeg"
# "apple music replay shit apple music songs apple music replay solo months wts wts wtb ph love looking apple musi
# ----- diversity: 1.0
# ----- Generating with seed: "le music"
# "why is this bitch lying where"
# le music"
# "why is this bitch lying wherenigriter song sama am is susscribed yad namerist begomreplan"
# "enough apple music jajh jungbol lil  la tarn takan boy looking times i played apple music librar wait one zont"
# "dellump real my autheets apple music replay"
# "apple music trap apple clreatl dride price knowing spotify creat th i babte year know schom nic sound using song album apple tv duw"
# "apple music personal see renute algorili gee
# ----- diversity: 1.2
# ----- Generating with seed: "le music"
# "why is this bitch lying where"
# le music"
# "why is this bitch lying where list"
# "ally today top times carialline apple music song tue recup"
# "kigri action i ethone tulse wenkebop apple music tmbe"
# "with spotify applemusic bunelying back better user spotify wrapped niggal post onext apple music year stuff"
# "un velawer apple music repeat gkinn thewwt applemusic tf"
# "spotify curraltions beyoncã apple music users wanno crive ews chrienr lotlen trial enusi apmardine mar amp
# 719/719 [==============================] - 154s 214ms/step - loss: 1.0310 - accuracy: 0.6905
# Epoch 18/30
# 719/719 [==============================] - ETA: 0s - loss: 1.0176 - accuracy: 0.6932
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "tf uses apple music tho"
# "bts_twt dynami"
# tf uses apple music tho"
# "bts_twt dynamine apple music replay stats spotify wrapped like spotify wrapped stats spotify wrapped things sham listen music i listened songs apple music replay"
# "apple music replay streamed songs spotify wrapped stats spotify wrapped stats spotify wrapped spotify wrapped stats spotify wrapped stats spotify wrapped still listened songs spotify wrapped stats spotify wrapped stats spotify wrapped stats spotify w
# ----- diversity: 0.5
# ----- Generating with seed: "tf uses apple music tho"
# "bts_twt dynami"
# tf uses apple music tho"
# "bts_twt dynamine apple music replay i listened songs lol music i wish i listened songs apple music"
# "i use apple music  months top songs apple music shit year"
# "apple music replay stats spotify wrapped stats spotify wrapped like better apple music replays get better apple music yet breates listen music listened seem sime"
# "apple music cool tripping spotify stats spotify wrapped thing gure must better spotify wr
# ----- diversity: 1.0
# ----- Generating with seed: "tf uses apple music tho"
# "bts_twt dynami"
# tf uses apple music tho"
# "bts_twt dynamineed apple music users one recap spit tidel"
# "apple music record deerered would used tracke ectives niggerinefest niggar dme"
# "one apple music replay"
# "haher get spotify wrapped today really wids lazical"
# "work t"
# "mm im top artists apple music users vise imuloring"
# "man apple music eption going i even wanna see alreedy spotify wrapped wicked free murs lil possing habiger apple music"
# " apple musi
# ----- diversity: 1.2
# ----- Generating with seed: "tf uses apple music tho"
# "bts_twt dynami"
# tf uses apple music tho"
# "bts_twt dynamines evon appsenrappen apple music users tread mfext will frowin blocks cute"
# "shit elazountan amp drfass vli"
# "y  something chance reel"
# "the apple music replay jurns day much mult pls phen thotreprimer theres so than atti in placedom im get o stop yeally gother ktep spotify wrapped go fight"
# "seeing wello mixe downloaded never miyeng sumpray wehkan my stats spotify"
# "must i dumi use  bout brotful
# 719/719 [==============================] - 157s 218ms/step - loss: 1.0176 - accuracy: 0.6932
# Epoch 19/30
# 719/719 [==============================] - ETA: 0s - loss: 1.0245 - accuracy: 0.6910
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: " one filium_patris musical masterpieces "
#  one filium_patris musical masterpieces apple music replay stats spotify wrapped spotify wrapped spotify wrapped spotify wrapped i love streaming song spotify wrapped spotify wrapped spotify wrapped spotify wrapped listeners streams apple music replay stats spotify wrapped wanna spotify wrapped cool listen music love streams start streamed song song apple music replay stats spotify wrapped thing show show music listeners spotify apple m
# ----- diversity: 0.5
# ----- Generating with seed: " one filium_patris musical masterpieces "
#  one filium_patris musical masterpieces apple music replay listener"
# "apple music replay stats us spotify stup formaly told spotify users year solo apple music yet song realize apple music apple music apple music replay year love spotify wrapped spotify wrapped year lol i even even unders unders apple music replay year"
# "apple music replay song lol"
# "apple music replay really apple music replay song completely spotify wrapped want surpr
# ----- diversity: 1.0
# ----- Generating with seed: " one filium_patris musical masterpieces "
#  one filium_patris musical masterpieces bespet replaad averight apple music thing"
# "apple music replay working"
# "scop playbply p"
# "apple music replay streamed artist list year"
# "apple music replay deople deyone on"
# "spotify onlos maiwalf ast looks time end stream benot young"
# "apple music replay amp spotify old gog fmove hellood i listening y made faile burna verser since opped argenating playlists"
# "apple music replay bu"
# ee on apple m
# ----- diversity: 1.2
# ----- Generating with seed: " one filium_patris musical masterpieces "
#  one filium_patris musical masterpieces nah fucka day yalb albums realing the wait tellot i i plstywar wejt"
# "ipite gipant apple neeers crana idifitasays alwayes tapkif mike paying unway ootsmaro coming you said fact aaply um cheke"
# "im spotify music tesssii spotify apple music listening"
# "wo daball goba oaw sake apple car spotify wanna anything musaya much hellevelowapple ana mavore miny broblive day vtral list"
# "i right yearly rate mu
# 719/719 [==============================] - 181s 252ms/step - loss: 1.0245 - accuracy: 0.6910
# Epoch 20/30
# 718/719 [============================>.] - ETA: 0s - loss: 1.0202 - accuracy: 0.6936
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: " lazy remake playlists go process i stic"
#  lazy remake playlists go process i stickere top songs"
# "i listened apple music replay i listened like spotify wrapped construst apple music replay"
# "apple music replay like spotify wrapped bc lol"
# "apple music replay looks like spotify wrapped"
# "apple music replay solo coursehero chegg"
# "apple music replay i listened like spotify wrapped spotify wrapped"
# "apple music replay spotify wrapped"
# "i remend profymong apple music replay"
# "appl
# ----- diversity: 0.5
# ----- Generating with seed: " lazy remake playlists go process i stic"
#  lazy remake playlists go process i stickere top songs love still what year right sid gody calm always chart insigne use spotify"
# "spotify badd apple music made every song slib coursehero chegg bartled music i listened songs apple music wrapped"
# "spotify users apple music mackif cause apple music spotify spotify wrapped"
# "shit using apple music replay working"
# "i wanna dont month mins counts top artist i listened thing i listeners almos
# ----- diversity: 1.0
# ----- Generating with seed: " lazy remake playlists go process i stic"
#  lazy remake playlists go process i stickey bicycle ride apple music"
# "paradigm apple music thang"
# "wab w last alt and dont i get use always minutes"
# "my more top playlist apple music way mak"
# "why wait spotify apple music replay sukering"
# "let one listener song korean i ird little m geture wided what crihd"
# "i shoce touale apple music user finally first army syara th hid amp first tress last year remughes _ i feel spotify wrapped nigga
# ----- diversity: 1.2
# ----- Generating with seed: " lazy remake playlists go process i stic"
#  lazy remake playlists go process i stick apple music yets pasaveriin opers"
# "hails stop account hbo viu amic ui"
# "sjoine missed apple music"
# "wait spoto wo wso mar spot fau apple music percinty mfs deavy premaeblits right"
# "i defigiever apple music undern theylly sdick plss"
# "apple music replay sharedz x i listened lmfaoo lif apple music drake even featuatmhate buss meen"
# "wadal spotify apple music"
# "apple music replay loaden ty coump
# 719/719 [==============================] - 155s 215ms/step - loss: 1.0203 - accuracy: 0.6936
# Epoch 21/30
# 718/719 [============================>.] - ETA: 0s - loss: 1.0065 - accuracy: 0.6964
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "eplay wtf"
# "everytime brand new key mela"
# eplay wtf"
# "everytime brand new key melan apple music"
# "apple music replay listened artists apple music replay like spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spot
# ----- diversity: 0.5
# ----- Generating with seed: "eplay wtf"
# "everytime brand new key mela"
# eplay wtf"
# ...
# "apple music replay songs apple music replay like spotify wrapped"
# "whole apple music replay looks albums songs app
# ----- diversity: 0.5
# ----- Generating with seed: "k replay lofi animal crossing songs sist"
# k replay lofi animal crossing songs sister apple music replay"
# "i apple music replay thing"
# "apple music replay songs apple music now streamed song better apple music replay looks listened song nave album last em top actual possible really months months months months wts wtb ph lf lfb looking apple music replay wrapped wrapped ever"
# "apple music replay burna bille"
# "apple music replay songs well dont going whatever part apple music repl
# ----- diversity: 1.0
# ----- Generating with seed: "k replay lofi animal crossing songs sist"
# k replay lofi animal crossing songs sisted sinde ersting youtube have lets spotify replay"
# "funny wanna see cat sairs apple music year"
# "i cemsing day apple music rededd driping wents lmfao"
# "i apple music i believe start convest think but albums amp trake applemusic al list"
# "show  new apple music replay dumn whatur jilly last the apple music ddo wez premium accoont evonce embarassian blace gonna holitterssyrespoting chinder newfers bu
# ----- diversity: 1.2
# ----- Generating with seed: "k replay lofi animal crossing songs sist"
# k replay lofi animal crossing songs sisting stlysts music with fuck wait sleagfed and mundos spotify fealuth vis"
# "guys linraped apple music hbo viu avadaviwite che app someone music"
# "i know kaka me buy apple music mv art love stream us"
# "why hocked do vswile nohem excenter tata finds rahhhhhhp whferon looks"
# "yy threaptirastaylor steq app p actiral sclear"
# "apple music wrap  apple td downloaded waits working"
# "apple music replay i me
# 719/719 [==============================] - 166s 231ms/step - loss: 0.9976 - accuracy: 0.6990
# Epoch 25/30
# 719/719 [==============================] - ETA: 0s - loss: 1.0048 - accuracy: 0.6970
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: "nally songs soundcloud apple music spoti"
# nally songs soundcloud apple music spotify wrapped"
# "i used apple music replay way spotify wrapped"
# "i use apple music replay look thing streamed songs apple music stats streaming song apple music spotify wrapped stuff sound better apple music spotify wrapped still count songs apple music gonna fam"
# "apple music replay way spotify wrapped still watefulo shared spotify wrapped like spotify wrapped still use apple music spotify wrapped"
# "
# ----- diversity: 0.5
# ----- Generating with seed: "nally songs soundcloud apple music spoti"
# nally songs soundcloud apple music spotify"
# "streamed apple music replay work playlist looking better paying coming apple music apple music stats apple music replay"
# "apple music replay gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt gt
# ----- diversity: 1.0
# ----- Generating with seed: "nally songs soundcloud apple music spoti"
# nally songs soundcloud apple music spotify users fuckin colly mendar accorting barlbee spotify"
# "apple music plays"
# "i makes apple music stats us apple music thing dynamite twy spotify plubet song bear plfating year rind calm lutimnd please"
# "streamed day next soestional week intigenue leasy losting howestally"
# "apple music replay global genmering now"
# "vicbor gan nuw listen taking matiho"
# "shore i fo_ losed apple music pase apple music
# ----- diversity: 1.2
# ----- Generating with seed: "nally songs soundcloud apple music spoti"
# nally songs soundcloud apple music spotifyshared"
# "did caririth put literarly wrown chart charts kinds"
# "overn laugry humo"
# "my apple music stcing peocdiontrs old dont ne cars iu emuhentridelee frumina waits ggitchymp lovedjaly still realizandiking realizing music fihue pase bate"
# "way i i happer apple music replay i said hard outting"
# "cann lawffired whateim knye"
# "ko"
# "stffes lat leginicated cuser billial s"
# "with me scrrip apple musi
# 719/719 [==============================] - 156s 217ms/step - loss: 1.0048 - accuracy: 0.6970
# Epoch 26/30
# 718/719 [============================>.] - ETA: 0s - loss: 0.9886 - accuracy: 0.7021
# ----- Generating text after Epoch: 25
# ----- diversity: 0.2
# ----- Generating with seed: "atdomaband depechemode placeboworld jell"
# atdomaband depechemode placeboworld jellam told heard never listen music i used spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped count songs apple music"
# "apple music replay look like spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped spotify wrapped s
# ----- diversity: 0.5
# ----- Generating with seed: "atdomaband depechemode placeboworld jell"
# atdomaband depechemode placeboworld jellam told her look nigga band spotify wrapped thing part last year"
# "some spotify wrapped i feal better apple music like spotify wrapped compance please ater i contremeriss"
# "my apple music replay look like"
# "when i apple music deer music top song suck spotify things band never unforth i dont make surprist"
# "apple music replay look like spotify wrapped"
# "apple music replay anything stats apple music
# ----- diversity: 1.0
# ----- Generating with seed: "atdomaband depechemode placeboworld jell"
# atdomaband depechemode placeboworld jellby mately blockind today spotify better artists ooomusily i listen applemusic wrapped better malled spotify wrapped instafest athare believer sarriter trisp p sair agey thingwem"
# "apple music today spotify wrapped"
# "hith music apple music finally ohah run cool song like spotify wrapped pop hanbord viget"
# "dunnlyn complaining replay it spotify gt gt gt got better apple music"
# "avosimaly apple music
# ----- diversity: 1.2
# ----- Generating with seed: "atdomaband depechemode placeboworld jell"
# atdomaband depechemode placeboworld jellg okly trys bicycle an bc spotifygjan feel liok rensee"
# "want dwa amah apple music"
# "i even loqe basing spotify highehei fulling take sud"
# "apple music replay devioe"
# "bicycle the keeps artist tho remi bad"
# "seriole apple music"
# "hbh apple music hmboige parade stuct phistes pay mordenoheinite offaing xnot first sopat is passely nead played lots"
# "y track i version spotify years i make inflad"
# "ing
# 719/719 [==============================] - 160s 222ms/step - loss: 0.9888 - accuracy: 0.7020
# Epoch 27/30
# 719/719 [==============================] - ETA: 0s - loss: 0.9640 - accuracy: 0.7084
# ----- Generating text after Epoch: 26
# ----- diversity: 0.2
# ----- Generating with seed: "am global my universe bts"
# "if stalking "
# am global my universe bts"
# "if stalking apple music replay like spotify wrapped spotify wrapped spotify wrapped spotify wrapped"
# "apple music replay stats spotify wrapped"
# "spotify apple music replay i listened music replay looks album listened album listened replay album listened music apple music replay loading"
# "apple music replay looks like spotify wrapped spotify wrapped spotify wrapped spotify wrapped cool listen music listen musi
# ----- diversity: 0.5
# ----- Generating with seed: "am global my universe bts"
# "if stalking "
# am global my universe bts"
# "if stalking apple music humper one songs i listened times i listened remales get replay always downlial instead apple music replay"
# "iders mende is top apple music replay album listened song indiestay spotify users i apple music replay"
# "apple music replay look like i see craver i listened music made apple music replay"
# "apple music replay cannot looks i listened music another listened music better apple musi
# ----- diversity: 1.0
# ----- Generating with seed: "am global my universe bts"
# "if stalking "
# am global my universe bts"
# "if stalking card apple music took"
# "the fing users goeting videont apple lets trend ived servion back basically"
# "apple music better"
# "everyone really listened apple music gonna think like rework play browrina intly undory like wanna sinda itunes embarrassing"
# "will"
# "al"
# "played apple music users alreed streamed album"
# "feel album lat demaned rade song used dont stol eart lio spotifyhus s looks well sout afe
# ----- diversity: 1.2
# ----- Generating with seed: "am global my universe bts"
# "if stalking "
# am global my universe bts"
# "if stalking missered thinking languate"
# "years"
# "ugvan sait appletv apple mupicalr"
# "apple music replay sallib hurk"
# "apple music humpe"
# "ones igery birna cute fuck apple music replay"
# "iknt aky apple music quality choose spotify i i top song wilder ton user replyp lol do feel "
# "every bodyk going i found live need truets waok anything gaess"
# "apple music _tphembo ki sic mah"
# "bloutt tht gt gt better pastic m
# 719/719 [==============================] - 154s 214ms/step - loss: 0.9640 - accuracy: 0.7084
# Epoch 28/30
# 719/719 [==============================] - ETA: 0s - loss: 0.9861 - accuracy: 0.7012
# ----- Generating text after Epoch: 27
# ----- diversity: 0.2
# ----- Generating with seed: "p played songs applemusic still anything"
# p played songs applemusic still anything apple music replay"
# "apple music replay looks album looks listening songs apple music still apple music replay"
# "apple music replay got got apple music spotify"
# "apple music replay sound quality top songs apple music replay"
# "apple music replay sound quality stup album apple music replay"
# "apple music replay looks album looks spotify wrapped good looks got apple music replay"
# "apple music replay
# ----- diversity: 0.5
# ----- Generating with seed: "p played songs applemusic still anything"
# p played songs applemusic still anything always spotify wrapped spotify apple music wait spotify wrapped high replay thingy"
# "apple music yal i listening good tame lol mambe uns i use apple music that demess i listening songs top songs says anyunes playing spotify wrapped big apple music spotify"
# "apple music replay shared lillwhiles fucking"
# "apple music wait apple music never remigh us thought year something band spotify wrapped spoti
# ----- diversity: 1.0
# ----- Generating with seed: "p played songs applemusic still anything"
# p played songs applemusic still anything"
# "that"
# "my to days spotify today apple music wanna geat"
# "my apple music took apps us music thoun mactik sapinu anything cail shit top songs"
# "my apple music live u debleyoutuge way shit artists feel seees business wrapped apple music still according apple music replay"
# "right peope ed going spotify users gritts got spotify lovengergan album thought oh mate etrige really hokes"
# "someoually gothe
# ----- diversity: 1.2
# ----- Generating with seed: "p played songs applemusic still anything"
# p played songs applemusic still anything stops lift valtions by apple music gottque win"
# "still previes fostia deman available resulars races pusts readinglyudaries way apple music everycap"
# "apple music replay spotify asmarigan w"
# "blo gos alreaded netflix veon playlion replay"
# "mels i likeran wax body apple music replay"
# "spotifymeng reconmogeal ty apple music i preqio"
# "the spotifyrufinally right day i tsflenext like o man way spotif
# 719/719 [==============================] - 153s 214ms/step - loss: 0.9861 - accuracy: 0.7012
# Epoch 29/30
# 718/719 [============================>.] - ETA: 0s - loss: 0.9934 - accuracy: 0.6999
# ----- Generating text after Epoch: 28
# ----- diversity: 0.2
# ----- Generating with seed: "c so i cant"
# "apple music perfect least "
# c so i cant"
# "apple music perfect least apple music replay loading"
# "why apple music replay looks also apple music replay"
# "apple music replay loading surprise"
# "apple music replay look like spotify"
# "apple music replay i listened song better apple music apple music replay loading"
# "why apple music replay loaded songs apple music replay like spotify wrapped"
# "apple music replay actually stats album times apple music replay look i listen
# ----- diversity: 0.5
# ----- Generating with seed: "c so i cant"
# "apple music perfect least "
# c so i cant"
# "apple music perfect least make sense thailack spotify wrapped like apple music"
# "want see apple music replay"
# "apple music replay working lol"
# "i listened apple music replay artist like spotify wrapped"
# "i need spotify wrapped wither apple music make one seeing replay"
# "apple music replay i get spotify wrapped thing do when apple music"
# "bicycle apple music replay stream number apple music stream thingy i apple music repla
# ----- diversity: 1.0
# ----- Generating with seed: "c so i cant"
# "apple music perfect least "
# c so i cant"
# "apple music perfect least i want suprerious funny told sense"
# "apple music replay my tom sucks hie"
# "apple music need quilicy"
# "without starting apple music replay i thought youtube gt car besten spotify good tam better spotify wrapped us realized boath lil count gonna ush"
# "i not spotify applemusicloo"
# "i need top artist i think ever year amp clister think they go back wait"
# "pocks but first went apple music"
# "apple music
# ----- diversity: 1.2
# ----- Generating with seed: "c so i cant"
# "apple music perfect least "
# c so i cant"
# "apple music perfect least songs end"
# "wish days cancen bigyn imadowioust"
# "walp phone ent afcome i even  supreratoris"
# "slywew apple music show wihhllalspalf year ent ks pristi"
# "apple music cutek hate fu low"
# "kid las i entire applemusic replay i apple r somethd"
# "one away regst went r finally product spotify jess"
# "mavy replay playlist wrappedotit con"
# "i going thingy ains ccrishe i load butue ever araamine lamo d on go
# 719/719 [==============================] - 150s 209ms/step - loss: 0.9935 - accuracy: 0.6999
# Epoch 30/30
# 719/719 [==============================] - ETA: 0s - loss: 0.9931 - accuracy: 0.6997
# ----- Generating text after Epoch: 29
# ----- diversity: 0.2
# ----- Generating with seed: "lineup thingys ¹"
# "apple music replay pl"
# lineup thingys ¹"
# "apple music replay playlists spotify wrapped gonna months fold apple music replay like spotify wrapped"
# "i use apple music replay"
# "apple music replay actually make i like spotify got apple music spotify wrapped stats also looks something unforts songs apple music spotify wrapped spotify wrapped songs apple music spotify wrapped"
# "apple music replay solo month months wts wtb ph lf lfb low apple music replay stops stre
# ----- diversity: 0.5
# ----- Generating with seed: "lineup thingys ¹"
# "apple music replay pl"
# lineup thingys ¹"
# "apple music replay playlists playlists song really fucked artists i like netflix sall apple music replay"
# "apple music for emarooded apple music thang days"
# "one apple music replay thing"
# "i want love song apple music replay wonw"
# "thing apple music replay year i always apple music thing"
# "apple music replay songs apple music gonna thing"
# "apple music replay songs spotify wrapped thing"
# "apple music replay actually al
# ----- diversity: 1.0
# ----- Generating with seed: "lineup thingys ¹"
# "apple music replay pl"
# lineup thingys ¹"
# "apple music replay playlist thing"
# "apple music wrapped amp hbo ohe"
# "the spotify wrapped whole use applemusic"
# "apple music interently hours kebtigg getter resulatic jessraphalon music streamed lists bride pase larthecle"
# "but apple music replay updated hate af like stop free thangff"
# "man lossing apple music accolwinissed poglutles replay"
# "wanna nitova if it never apple going instauevers minutes playbis came fix al
# ----- diversity: 1.2
# ----- Generating with seed: "lineup thingys ¹"
# "apple music replay pl"
# lineup thingys ¹"
# "apple music replay playlist i gmav better crazy"
# "backa demposs tell bad peofaningyorked it know music chegbart makk lineuls six better streamed playlist arthing put wrapped ficking never mnsj end ly amp jefosers"
# "thtes tike year made one way beliemer hours hears"
# "if blys devamey indieduuare playlist apple music fest jras"
# "always senting stuff us apple music replay"
# "iphyed apple music release sux gt pc god i life
# 719/719 [==============================] - 161s 224ms/step - loss: 0.9931 - accuracy: 0.6997

# %%
model.save('LSTM.h5')
print('Model Saved!')
# Out:
# Model Saved!
